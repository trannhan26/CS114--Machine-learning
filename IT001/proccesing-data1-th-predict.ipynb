# %%
import sys  # System-specific parameters and functions
import numpy as np  # Fundamental package for scientific computing with Python
import pandas as pd  # Powerful data structures for data manipulation and analysis
from datetime import datetime  # Basic date and time types
import warnings  # Warning control
warnings.filterwarnings('ignore')  # Ignore warnings

# %%
df = pd.read_csv(('C:/Users/nguye/Downloads/cs114/data-tbtl/annonimized.csv'))
df = df[(df['is_final'] != 0) | (df['pre_score'] != 10000)]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 288863 entries, 0 to 295197
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   concat('it001',`assignment_id`)  288863 non-null  object
#  1   concat('it001',`problem_id`)     288863 non-null  object
#  2   concat('it001', username)        288863 non-null  object
#  3   is_final                         288863 non-null  int64
#  4   status                           288863 non-null  object
#  5   pre_score                        288863 non-null  int64
#  6   coefficient                      288863 non-null  int64
#  7   concat('it001',`language_id`)    288863 non-null  object
#  8   created_at                       288863 non-null  object
#  9   updated_at                       288863 non-null  object
#  10  judgement                        288863 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 26.4+ MB

# %%
df = df.rename(columns={"concat('it001',`assignment_id`)": 'assignment_id'})
df = df.rename(columns={"concat('it001',`problem_id`)":'problem_id'})
df = df.rename(columns={"concat('it001', username)":'username'})

# %%
df = df.drop(["concat('it001',`language_id`)", 'updated_at'], axis=1)

# %%
def calculate_frequency_vector(student_df):
    a = pd.to_datetime(student_df['created_at'], format='%m-%d %H:%M:%S', errors='coerce').dt.hour
    a = a.dropna()  # Drop rows with NaT (errors in parsing)

    hour_counts = a.value_counts().sort_index()
    frequency_vector = np.zeros(24)
    for hour, count in hour_counts.items():
        hour = int(hour)
        frequency_vector[hour] = count
    return frequency_vector

# Dictionary to store frequency vectors for each student
frequency_vectors = {}

# Iterate over each unique student and calculate their frequency vector
for username in df["username"].unique():
    student_df = df[df["username"] == username]
    frequency_vectors[username] = calculate_frequency_vector(student_df)

# %%
frequency_df = pd.DataFrame.from_dict(frequency_vectors, orient='index', columns=[f'hour_{i}' for i in range(24)]).reset_index()
frequency_df.rename(columns={'index': "username"}, inplace=True)

# %%
df = df.merge(frequency_df, on="username")

# %%
fixed_year = 2024  # Chọn một năm bất kỳ
df['created_at'] = [f"{fixed_year}-{date}" for date in df['created_at']]

# %%
df['created_at'] = pd.to_datetime(df['created_at'])
def adjust_year(date):
    if date.month >= 9:
        return date.replace(year=date.year - 1)
    return date

# Áp dụng hàm này vào cột 'created_at'
df['created_at'] = df['created_at'].apply(adjust_year)

# %%
df['created_at'] = pd.to_datetime(df['created_at'])

# %% [markdown]
# # Số lượng assignment và problem

# %%
num_assigmnet1 = df.groupby(["username"])['assignment_id'].nunique().reset_index().rename(columns={'assignment_id': 'num_assigmnet1'})
num_problem = df.groupby(["username"])["problem_id"].nunique().reset_index().rename(columns={'problem_id': 'num_problem'})
submit_count = df.groupby(["username"])["problem_id"].count().reset_index().rename(columns={'problem_id': 'submit_count'})

# %% [markdown]
# # Số lần nộp SCORE và Khác

# %%
count_non_score = df[df['status'] != 'SCORE'].groupby("username").size().reset_index().rename(columns={0: 'count_NON_SCORE'})
count_score = df[df['status'] == 'SCORE'].groupby("username").size().reset_index().rename(columns={0: 'count_SCORE'})

# %% [markdown]
# # Số lần nộp is_final

# %%
count_is_final = df[df['is_final'] == 1].groupby("username").size().reset_index().rename(columns={0: 'count_is_final'})

# %% [markdown]
# # Điểm số trung bình

# %%
mean_pre_score = df.groupby(["username"])["pre_score"].mean().reset_index().rename(columns={'pre_score': 'mean_pre_score'})

# %% [markdown]
# # Tỉ số số lần nộp và assigment

# %%
count_of_assignments = df.groupby(["username"])["problem_id"].count() / df.groupby(["username"])["assignment_id"].nunique()

# %%
count_of_assignments = count_of_assignments.reset_index().rename(columns={0: 'count_of_assignments'})

# %%
count_of_assignments
# Out:
#                                       username  count_of_assignments
# 0     00b6dd4fc7eb817e03708c532016ef30ce564a61             19.857143
# 1     00bef8afee8f3c595d535c9c03c490cac1a4f021             27.333333
# 2     01122b3ef7e59b84189e65985305f575d6bdf83c             27.857143
# 3     0134f9f410c65ad0e8c2254a7e9288670e02a183             23.750000
# 4     013de369c439ab0ead8aa7da64423aa395a8be39             13.250000
# ...                                        ...                   ...
# 1484  feb8a2859a011c59efd22ed419cb69288fe03627              7.555556
# 1485  fef4a3263ed9a8ab14d457694bb8fd86ccd98312             42.500000
# 1486  ff12d6e2ab80696ed8e22fbe5497e96c68d29076             72.333333
# 1487  ff3fa2ec64294f37ae968159f810ebeda7966c51             13.428571
# 1488  ffe872165621d735a48bb5db0c71dd5195cba359             35.700000
#
# [1489 rows x 2 columns]

# %% [markdown]
# # Tỉ số số lần nộp và problem

# %%
count_of_problems = df.groupby(["username"])["problem_id"].count() / df.groupby(["username"])["problem_id"].nunique()
count_of_problems = count_of_problems.reset_index().rename(columns={0: 'count_of_problems'})

# %%
tgia = df.groupby(["username", "problem_id"])["pre_score"].max()
tgia = tgia.groupby(["username"]).apply(lambda x: (x != 10000).sum()) / tgia.groupby(["username"]).count()

# %%
tgia = tgia.reset_index().rename(columns={"pre_score": 'ratio_not_10000'})

# %%
mean_submit_problem = df.groupby(["username", "problem_id"])["problem_id"].count()
mean_submit_problem = mean_submit_problem.groupby("username").mean().reset_index().rename(columns={"problem_id": 'mean_submit_problem'})

# %%
mean_submit_assignment = df.groupby(["username", "assignment_id"])["assignment_id"].count()
mean_submit_assignment = mean_submit_problem.groupby("username").mean().reset_index().rename(columns={"assignment_id": 'mean_submit_assignment'})

# %%
mean_time_problem = df.groupby(["username", "problem_id"])['created_at'].agg(lambda x: (x.max() - x.min()).total_seconds() / 3600)
mean_time_problem = (mean_time_problem.groupby(["username"]).mean()/10).reset_index().rename(columns={"created_at": 'mean_submit_problem'})

# %%
mean_time_assignment = df.groupby(["username", "assignment_id"])['created_at'].agg(lambda x: (x.max() - x.min()).total_seconds() / 3600)
mean_time_assignment = (mean_time_assignment.groupby(["username"]).mean()/10).reset_index().rename(columns={"created_at": 'mean_submit_assignment'})

# %%
df = df.merge(num_assigmnet1, on="username")
df = df.merge(num_problem, on="username")
df = df.merge(submit_count, on="username")
df = df.merge(count_non_score, on="username")
df = df.merge(count_score, on="username")
df = df.merge(count_is_final, on="username")
df = df.merge(mean_pre_score, on="username")
df = df.merge(count_of_assignments, on="username")
df = df.merge(tgia, on="username")
df = df.merge(count_of_problems, on="username")
df = df.merge(mean_submit_problem, on="username")
df = df.merge(mean_time_problem, on="username")

# %%
df = df.drop(['problem_id_x'],axis = 1)

# %%
df = df.drop(['problem_id_y'],axis = 1)

# %%
df = df.drop(['assignment_id'],axis = 1)

# %%
df.columns
# Out:
# Index(['username', 'is_final', 'status', 'pre_score', 'coefficient',
#        'created_at', 'judgement', 'hour_0', 'hour_1', 'hour_2', 'hour_3',
#        'hour_4', 'hour_5', 'hour_6', 'hour_7', 'hour_8', 'hour_9', 'hour_10',
#        'hour_11', 'hour_12', 'hour_13', 'hour_14', 'hour_15', 'hour_16',
#        'hour_17', 'hour_18', 'hour_19', 'hour_20', 'hour_21', 'hour_22',
#        'hour_23', 'num_assigmnet1', 'num_problem', 'submit_count',
#        'count_NON_SCORE', 'count_SCORE', 'count_is_final', 'mean_pre_score',
#        'count_of_assignments', 'ratio_not_10000', 'mean_submit_problem_x',
#        'mean_submit_problem_y'],
#       dtype='object')

# %%
# !pip install lightgbm catboost
# Out:
# Requirement already satisfied: lightgbm in c:\users\nguye\anaconda3\lib\site-packages (4.5.0)
# Requirement already satisfied: catboost in c:\users\nguye\anaconda3\lib\site-packages (1.2.7)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\nguye\anaconda3\lib\site-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in c:\users\nguye\anaconda3\lib\site-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: graphviz in c:\users\nguye\anaconda3\lib\site-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in c:\users\nguye\anaconda3\lib\site-packages (from catboost) (3.8.4)
# Requirement already satisfied: pandas>=0.24 in c:\users\nguye\anaconda3\lib\site-packages (from catboost) (2.2.3)
# Requirement already satisfied: plotly in c:\users\nguye\anaconda3\lib\site-packages (from catboost) (5.19.0)
# Requirement already satisfied: six in c:\users\nguye\anaconda3\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nguye\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nguye\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nguye\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nguye\anaconda3\lib\site-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\nguye\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nguye\anaconda3\lib\site-packages (from matplotlib->catboost) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nguye\anaconda3\lib\site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\nguye\anaconda3\lib\site-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\nguye\anaconda3\lib\site-packages (from matplotlib->catboost) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nguye\anaconda3\lib\site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\nguye\anaconda3\lib\site-packages (from plotly->catboost) (8.2.2)

# %%
pip install optuna
# Out:
# Requirement already satisfied: optuna in c:\users\nguye\anaconda3\lib\site-packages (4.1.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: alembic>=1.5.0 in c:\users\nguye\anaconda3\lib\site-packages (from optuna) (1.14.0)
# Requirement already satisfied: colorlog in c:\users\nguye\anaconda3\lib\site-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in c:\users\nguye\anaconda3\lib\site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\nguye\anaconda3\lib\site-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\nguye\anaconda3\lib\site-packages (from optuna) (2.0.25)
# Requirement already satisfied: tqdm in c:\users\nguye\anaconda3\lib\site-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in c:\users\nguye\anaconda3\lib\site-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in c:\users\nguye\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.8)
# Requirement already satisfied: typing-extensions>=4 in c:\users\nguye\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\nguye\anaconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.0.1)
# Requirement already satisfied: colorama in c:\users\nguye\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\nguye\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import os
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.metrics import mean_squared_error as MSE
import lightgbm as lgb
import optuna
from sklearn.model_selection import cross_validate
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.metrics import r2_score
from sklearn.ensemble import VotingRegressor
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer, KNNImputer

# %%
train_term1 = df.drop(['is_final','status','pre_score','coefficient','created_at','judgement'], axis = 1)

# %%
test_term1 = train_term1

# %%
test_term1
# Out:
#                                         username  hour_0  hour_1  hour_2  \
# 0       ed9eaeb6a707f50154024b24d7efcb874a9795dd     6.0     6.0     1.0
# 1       ed9eaeb6a707f50154024b24d7efcb874a9795dd     6.0     6.0     1.0
# 2       ed9eaeb6a707f50154024b24d7efcb874a9795dd     6.0     6.0     1.0
# 3       ed9eaeb6a707f50154024b24d7efcb874a9795dd     6.0     6.0     1.0
# 4       ed9eaeb6a707f50154024b24d7efcb874a9795dd     6.0     6.0     1.0
# ...                                          ...     ...     ...     ...
# 288284  232cce96362898f08e9150ba244adaf2d6583ab2     0.0     0.0    10.0
# 288285  232cce96362898f08e9150ba244adaf2d6583ab2     0.0     0.0    10.0
# 288286  232cce96362898f08e9150ba244adaf2d6583ab2     0.0     0.0    10.0
# 288287  232cce96362898f08e9150ba244adaf2d6583ab2     0.0     0.0    10.0
# 288288  232cce96362898f08e9150ba244adaf2d6583ab2     0.0     0.0    10.0
#
#         hour_3  hour_4  hour_5  hour_6  hour_7  hour_8  ...  num_problem  \
# 0          1.0     6.0     8.0     5.0    11.0    17.0  ...           58
# 1          1.0     6.0     8.0     5.0    11.0    17.0  ...           58
# 2          1.0     6.0     8.0     5.0    11.0    17.0  ...           58
# 3          1.0     6.0     8.0     5.0    11.0    17.0  ...           58
# 4          1.0     6.0     8.0     5.0    11.0    17.0  ...           58
# ...        ...     ...     ...     ...     ...     ...  ...          ...
# 288284     7.0     2.0     8.0     4.0     6.0    20.0  ...           98
# 288285     7.0     2.0     8.0     4.0     6.0    20.0  ...           98
# 288286     7.0     2.0     8.0     4.0     6.0    20.0  ...           98
# 288287     7.0     2.0     8.0     4.0     6.0    20.0  ...           98
# 288288     7.0     2.0     8.0     4.0     6.0    20.0  ...           98
#
#         submit_count  count_NON_SCORE  count_SCORE  count_is_final  \
# 0                136               34          102              58
# 1                136               34          102              58
# 2                136               34          102              58
# 3                136               34          102              58
# 4                136               34          102              58
# ...              ...              ...          ...             ...
# 288284           216               45          171              98
# 288285           216               45          171              98
# 288286           216               45          171              98
# 288287           216               45          171              98
# 288288           216               45          171              98
#
#         mean_pre_score  count_of_assignments  ratio_not_10000  \
# 0          5202.000000             27.200000         0.034483
# 1          5202.000000             27.200000         0.034483
# 2          5202.000000             27.200000         0.034483
# 3          5202.000000             27.200000         0.034483
# 4          5202.000000             27.200000         0.034483
# ...                ...                   ...              ...
# 288284     5680.976852             19.636364         0.020408
# 288285     5680.976852             19.636364         0.020408
# 288286     5680.976852             19.636364         0.020408
# 288287     5680.976852             19.636364         0.020408
# 288288     5680.976852             19.636364         0.020408
#
#         mean_submit_problem_x  mean_submit_problem_y
# 0                    2.344828               0.177979
# 1                    2.344828               0.177979
# 2                    2.344828               0.177979
# 3                    2.344828               0.177979
# 4                    2.344828               0.177979
# ...                       ...                    ...
# 288284               2.204082               1.677821
# 288285               2.204082               1.677821
# 288286               2.204082               1.677821
# 288287               2.204082               1.677821
# 288288               2.204082               1.677821
#
# [288289 rows x 36 columns]

# %%
test_term1.drop_duplicates(subset='username', keep='first', inplace=True)

# %%
qt_train = pd.read_csv('C:/Users/nguye/Downloads/cs114/public_it001/th-public.csv')

# %%
qt_train.isnull().sum()
qt_train = qt_train.rename(columns={"hash":'username'})
qt_train.dropna(inplace=True)
train_term1 = train_term1.merge(qt_train, on='username', how='inner')
train_term1.drop_duplicates(subset='username', keep='first', inplace=True)
train_term1['TH'] = train_term1['TH'].str.replace('\xa0', ' ', regex=True)
train_term1['TH'] = train_term1['TH'].replace(' ', np.nan).astype(float)
train_term1.dropna(inplace=True)

# %%
train_term1.columns
# Out:
# Index(['username', 'hour_0', 'hour_1', 'hour_2', 'hour_3', 'hour_4', 'hour_5',
#        'hour_6', 'hour_7', 'hour_8', 'hour_9', 'hour_10', 'hour_11', 'hour_12',
#        'hour_13', 'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_18',
#        'hour_19', 'hour_20', 'hour_21', 'hour_22', 'hour_23', 'num_assigmnet1',
#        'num_problem', 'submit_count', 'count_NON_SCORE', 'count_SCORE',
#        'count_is_final', 'mean_pre_score', 'count_of_assignments',
#        'ratio_not_10000', 'mean_submit_problem_x', 'mean_submit_problem_y',
#        'TH'],
#       dtype='object')

# %%
X_train= train_term1.drop(columns=["TH", "username"])
y = train_term1['TH']
y = y.astype(float)

# %%
y = np.asarray(y)
X_pca = np.asarray(X_train)

# %%
def objective_lgb(trial):
    params = {
        "objective": "regression",
        "metric": "rmse",
        "n_estimators": 1000,
        "verbosity": -1,
        "bagging_freq": 1,
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.1, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 2**10),
        "subsample": trial.suggest_float("subsample", 0.05, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.05, 1.0),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 1, 100),
        'device': 'gpu',
    }
    cv = KFold(n_splits=5, shuffle=True,random_state = 42)
    r2_list = []

    for train_index, test_index in cv.split(X_pca,y):
        X_train_fold, X_test = X_pca[train_index], X_pca[test_index]
        y_train, y_test = y[train_index], y[test_index]

        model = lgb.LGBMRegressor(**params)

        model.fit(X_train_fold, y_train)
        y_pred = model.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        r2_list.append(r2)

    return np.mean(r2_list)

# %%
def objective_cat(trial):
    params = {
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
        'depth': trial.suggest_int('depth', 3, 8),
        'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10),
        'iterations': trial.suggest_int('iterations', 100, 1000),
        'eval_metric': 'RMSE',
        'random_seed': 42,
        'verbose': False,
        'loss_function':'RMSE',
        'task_type': 'GPU'
    }

    cv = KFold(n_splits=5, shuffle=True,random_state = 42)
    r2_list = []

    for train_index, test_index in cv.split(X_pca,y):
        X_train_fold, X_test = X_pca[train_index], X_pca[test_index]
        y_train, y_test = y[train_index], y[test_index]
        model = CatBoostRegressor(**params)
        model.fit(X_train_fold, y_train, eval_set=(X_test, y_test), early_stopping_rounds=10)
        y_pred = model.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        r2_list.append(r2)

    return np.mean(r2_list)

# %%
study_lgb = optuna.create_study(direction="minimize")
study_lgb.optimize(objective_lgb, n_trials=30)
print('Best parameters for LightGBM:', study_lgb.best_params)
# Out:
# [I 2025-01-18 18:31:10,232] A new study created in memory with name: no-name-80d62078-3ccf-4bae-91b5-544fba868959
# [I 2025-01-18 18:31:53,885] Trial 0 finished with value: 0.27699744541833315 and parameters: {'learning_rate': 0.0024069833090308787, 'num_leaves': 925, 'subsample': 0.5780190428682749, 'colsample_bytree': 0.7831117228406884, 'min_data_in_leaf': 88}. Best is trial 0 with value: 0.27699744541833315.
# [I 2025-01-18 18:34:00,468] Trial 1 finished with value: 0.3651107936545099 and parameters: {'learning_rate': 0.024552404225557583, 'num_leaves': 234, 'subsample': 0.8445886958749642, 'colsample_bytree': 0.19057079114522496, 'min_data_in_leaf': 54}. Best is trial 0 with value: 0.27699744541833315.
# [I 2025-01-18 18:35:43,965] Trial 2 finished with value: 0.31246560010771274 and parameters: {'learning_rate': 0.04141935789413202, 'num_leaves': 591, 'subsample': 0.6597154964876404, 'colsample_bytree': 0.05346487794010413, 'min_data_in_leaf': 37}. Best is trial 0 with value: 0.27699744541833315.
# [I 2025-01-18 18:38:37,058] Trial 3 finished with value: 0.3177675512555207 and parameters: {'learning_rate': 0.04426908560592913, 'num_leaves': 159, 'subsample': 0.36268672784909917, 'colsample_bytree': 0.9188215450670638, 'min_data_in_leaf': 65}. Best is trial 0 with value: 0.27699744541833315.
# [I 2025-01-18 18:40:34,232] Trial 4 finished with value: -0.013884182271661327 and parameters: {'learning_rate': 0.027801037155204596, 'num_leaves': 190, 'subsample': 0.05894285584930162, 'colsample_bytree': 0.6197509120418282, 'min_data_in_leaf': 52}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 18:42:20,988] Trial 5 finished with value: -0.013884182271661327 and parameters: {'learning_rate': 0.024824382082713894, 'num_leaves': 421, 'subsample': 0.052387261152081345, 'colsample_bytree': 0.604601352766003, 'min_data_in_leaf': 38}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 18:47:55,532] Trial 6 finished with value: 0.311238351507565 and parameters: {'learning_rate': 0.0010381553928942738, 'num_leaves': 722, 'subsample': 0.9732694852450302, 'colsample_bytree': 0.9101447841287406, 'min_data_in_leaf': 12}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 18:50:47,008] Trial 7 finished with value: 0.3203197944764514 and parameters: {'learning_rate': 0.0072057716503256385, 'num_leaves': 15, 'subsample': 0.3589915995131811, 'colsample_bytree': 0.5956023648810383, 'min_data_in_leaf': 64}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 18:52:43,645] Trial 8 finished with value: 0.33621471609797615 and parameters: {'learning_rate': 0.08989504937955334, 'num_leaves': 193, 'subsample': 0.8169617374233328, 'colsample_bytree': 0.8334025229122787, 'min_data_in_leaf': 29}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 18:53:16,775] Trial 9 finished with value: 0.32844101577733964 and parameters: {'learning_rate': 0.02474598705806159, 'num_leaves': 314, 'subsample': 0.638226542191866, 'colsample_bytree': 0.8503398626618414, 'min_data_in_leaf': 97}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 18:55:51,104] Trial 10 finished with value: -0.013884182271661327 and parameters: {'learning_rate': 0.0080807519141818, 'num_leaves': 536, 'subsample': 0.09595019898974469, 'colsample_bytree': 0.3729770940078788, 'min_data_in_leaf': 78}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 18:57:34,654] Trial 11 finished with value: -0.013884182271661327 and parameters: {'learning_rate': 0.01275476676212636, 'num_leaves': 417, 'subsample': 0.07793844556820394, 'colsample_bytree': 0.5820138945325836, 'min_data_in_leaf': 37}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 19:01:42,416] Trial 12 finished with value: 0.26325898100361683 and parameters: {'learning_rate': 0.09747283470034357, 'num_leaves': 39, 'subsample': 0.2302302497772482, 'colsample_bytree': 0.4261886025572412, 'min_data_in_leaf': 5}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 19:03:38,119] Trial 13 finished with value: 0.36761479840133304 and parameters: {'learning_rate': 0.01895027243197412, 'num_leaves': 390, 'subsample': 0.2403362277212095, 'colsample_bytree': 0.6771033197998034, 'min_data_in_leaf': 22}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 19:05:49,186] Trial 14 finished with value: 0.2766551457804193 and parameters: {'learning_rate': 0.0046379311880285125, 'num_leaves': 752, 'subsample': 0.2112262370794249, 'colsample_bytree': 0.443100459030526, 'min_data_in_leaf': 48}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 19:08:09,773] Trial 15 finished with value: 0.3256915631977472 and parameters: {'learning_rate': 0.049751032915488144, 'num_leaves': 455, 'subsample': 0.42339646386774205, 'colsample_bytree': 0.6660507473687411, 'min_data_in_leaf': 51}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 19:09:57,779] Trial 16 finished with value: -0.013884182271661327 and parameters: {'learning_rate': 0.016889082317108294, 'num_leaves': 289, 'subsample': 0.06427734999373985, 'colsample_bytree': 0.7317378041705628, 'min_data_in_leaf': 69}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 19:12:07,050] Trial 17 finished with value: 0.2828080259709683 and parameters: {'learning_rate': 0.03408036080310519, 'num_leaves': 623, 'subsample': 0.16290345276057408, 'colsample_bytree': 0.3001921380154293, 'min_data_in_leaf': 42}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 19:14:25,237] Trial 18 finished with value: 0.3994821281105511 and parameters: {'learning_rate': 0.004526682772171569, 'num_leaves': 123, 'subsample': 0.46648270803429603, 'colsample_bytree': 0.514238725502675, 'min_data_in_leaf': 22}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 19:15:58,239] Trial 19 finished with value: 0.3000511666015057 and parameters: {'learning_rate': 0.06403398424189428, 'num_leaves': 332, 'subsample': 0.335835292752016, 'colsample_bytree': 0.5507424585120466, 'min_data_in_leaf': 57}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 19:17:09,239] Trial 20 finished with value: -0.013884182271661327 and parameters: {'learning_rate': 0.01191480282201285, 'num_leaves': 1012, 'subsample': 0.15332246635874971, 'colsample_bytree': 0.28029007466325656, 'min_data_in_leaf': 77}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 19:18:18,646] Trial 21 finished with value: -0.013884182271661327 and parameters: {'learning_rate': 0.007947533731831977, 'num_leaves': 530, 'subsample': 0.06769960216341664, 'colsample_bytree': 0.4174486865828574, 'min_data_in_leaf': 80}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 19:19:34,398] Trial 22 finished with value: -0.013884182271661327 and parameters: {'learning_rate': 0.028797325475029143, 'num_leaves': 496, 'subsample': 0.1368839149381476, 'colsample_bytree': 0.3446628021366216, 'min_data_in_leaf': 99}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 19:20:53,422] Trial 23 finished with value: 0.28585173176638606 and parameters: {'learning_rate': 0.015941363297061525, 'num_leaves': 675, 'subsample': 0.27192856355885775, 'colsample_bytree': 0.4874749461400805, 'min_data_in_leaf': 77}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 19:22:02,979] Trial 24 finished with value: -0.013884182271661327 and parameters: {'learning_rate': 0.005135651280795175, 'num_leaves': 819, 'subsample': 0.05337156314453001, 'colsample_bytree': 0.6539144688447248, 'min_data_in_leaf': 29}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 19:23:17,631] Trial 25 finished with value: 0.2072725350176369 and parameters: {'learning_rate': 0.00956740053832032, 'num_leaves': 536, 'subsample': 0.14236740455220093, 'colsample_bytree': 0.23313534392561214, 'min_data_in_leaf': 43}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 19:24:30,087] Trial 26 finished with value: 0.22475920174646663 and parameters: {'learning_rate': 0.022709122499222995, 'num_leaves': 373, 'subsample': 0.2831365247259956, 'colsample_bytree': 0.3840182301586898, 'min_data_in_leaf': 87}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 19:25:38,566] Trial 27 finished with value: -0.013884182271661327 and parameters: {'learning_rate': 0.0028137738194668623, 'num_leaves': 244, 'subsample': 0.13619127548013657, 'colsample_bytree': 0.9829383994993665, 'min_data_in_leaf': 59}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 19:27:07,804] Trial 28 finished with value: 0.3154123116082331 and parameters: {'learning_rate': 0.05782974343890084, 'num_leaves': 102, 'subsample': 0.17949678040108852, 'colsample_bytree': 0.16176476248770183, 'min_data_in_leaf': 29}. Best is trial 4 with value: -0.013884182271661327.
# [I 2025-01-18 19:27:16,785] Trial 29 finished with value: 0.25001401533997325 and parameters: {'learning_rate': 0.0017949132385016834, 'num_leaves': 888, 'subsample': 0.5781273005757521, 'colsample_bytree': 0.7690136593910003, 'min_data_in_leaf': 89}. Best is trial 4 with value: -0.013884182271661327.
# Best parameters for LightGBM: {'learning_rate': 0.027801037155204596, 'num_leaves': 190, 'subsample': 0.05894285584930162, 'colsample_bytree': 0.6197509120418282, 'min_data_in_leaf': 52}

# %%
study_cat = optuna.create_study(direction='minimize')
study_cat.optimize(objective_cat, n_trials=30)
print('Best parameters for CatBoost:', study_cat.best_params)
# Out:
# [I 2025-01-18 19:27:16,883] A new study created in memory with name: no-name-caa6644e-6bcd-4b82-9be0-b50d5da7f445
# [I 2025-01-18 19:27:32,042] Trial 0 finished with value: 0.3569567325855693 and parameters: {'learning_rate': 0.05705606840243827, 'depth': 3, 'l2_leaf_reg': 0.011030825009341338, 'iterations': 617}. Best is trial 0 with value: 0.3569567325855693.
# [I 2025-01-18 19:27:45,408] Trial 1 finished with value: 0.37819815752584834 and parameters: {'learning_rate': 0.035294701737456184, 'depth': 7, 'l2_leaf_reg': 0.021170023347865042, 'iterations': 201}. Best is trial 0 with value: 0.3569567325855693.
# [I 2025-01-18 19:27:52,310] Trial 2 finished with value: 0.34469374462703606 and parameters: {'learning_rate': 0.028344475306993994, 'depth': 4, 'l2_leaf_reg': 0.00681180826588329, 'iterations': 100}. Best is trial 2 with value: 0.34469374462703606.
# [I 2025-01-18 19:27:57,539] Trial 3 finished with value: 0.36909313335015204 and parameters: {'learning_rate': 0.09969195118959813, 'depth': 6, 'l2_leaf_reg': 0.08333702885884747, 'iterations': 474}. Best is trial 2 with value: 0.34469374462703606.
. Best is trial 16 with value: 0.2511054289192964.
# [I 2025-01-18 19:33:08,678] Trial 17 finished with value: 0.3651352826398954 and parameters: {'learning_rate': 0.013876612852130297, 'depth': 4, 'l2_leaf_reg': 0.0050908687365150305, 'iterations': 305}. Best is trial 16 with value: 0.2511054289192964.
# [I 2025-01-18 19:34:36,529] Trial 18 finished with value: 0.3605416005115106 and parameters: {'learning_rate': 0.016793383394229203, 'depth': 8, 'l2_leaf_reg': 0.03447076972899832, 'iterations': 989}. Best is trial 16 with value: 0.2511054289192964.
# [I 2025-01-18 19:35:07,958] Trial 19 finished with value: 0.36061057706602445 and parameters: {'learning_rate': 0.024328342512284766, 'depth': 4, 'l2_leaf_reg': 0.004179273244106198, 'iterations': 710}. Best is trial 16 with value: 0.2511054289192964.
# [I 2025-01-18 19:35:16,981] Trial 20 finished with value: 0.37409424734074714 and parameters: {'learning_rate': 0.0503784810478855, 'depth': 6, 'l2_leaf_reg': 0.9547472596759937, 'iterations': 380}. Best is trial 16 with value: 0.2511054289192964.
# [I 2025-01-18 19:35:24,429] Trial 21 finished with value: 0.25766689080262123 and parameters: {'learning_rate': 0.010001949704012865, 'depth': 5, 'l2_leaf_reg': 0.003035759325971693, 'iterations': 103}. Best is trial 16 with value: 0.2511054289192964.
# [I 2025-01-18 19:35:43,096] Trial 22 finished with value: 0.3542733625398101 and parameters: {'learning_rate': 0.012500875283650327, 'depth': 4, 'l2_leaf_reg': 0.0035489702909349266, 'iterations': 250}. Best is trial 16 with value: 0.2511054289192964.
# [I 2025-01-18 19:35:53,549] Trial 23 finished with value: 0.3100184183871432 and parameters: {'learning_rate': 0.015491908824188497, 'depth': 5, 'l2_leaf_reg': 0.012711704247640964, 'iterations': 106}. Best is trial 16 with value: 0.2511054289192964.
# [I 2025-01-18 19:36:10,577] Trial 24 finished with value: 0.3255117300054825 and parameters: {'learning_rate': 0.010495583084367969, 'depth': 6, 'l2_leaf_reg': 0.0030834703966571187, 'iterations': 170}. Best is trial 16 with value: 0.2511054289192964.
# [I 2025-01-18 19:36:25,437] Trial 25 finished with value: 0.34584869755352343 and parameters: {'learning_rate': 0.012576593559301708, 'depth': 4, 'l2_leaf_reg': 0.008336201520441585, 'iterations': 222}. Best is trial 16 with value: 0.2511054289192964.
# [I 2025-01-18 19:36:48,450] Trial 26 finished with value: 0.3551869192905201 and parameters: {'learning_rate': 0.010076774761879763, 'depth': 5, 'l2_leaf_reg': 0.029885855677680612, 'iterations': 295}. Best is trial 16 with value: 0.2511054289192964.
# [I 2025-01-18 19:36:55,044] Trial 27 finished with value: 0.3359283473442618 and parameters: {'learning_rate': 0.02058888791452392, 'depth': 3, 'l2_leaf_reg': 0.002769423630450181, 'iterations': 158}. Best is trial 16 with value: 0.2511054289192964.
# [I 2025-01-18 19:37:14,097] Trial 28 finished with value: 0.37464578622351785 and parameters: {'learning_rate': 0.016362993012225862, 'depth': 4, 'l2_leaf_reg': 0.22985141946889345, 'iterations': 372}. Best is trial 16 with value: 0.2511054289192964.
# [I 2025-01-18 19:37:32,411] Trial 29 finished with value: 0.36005506707209955 and parameters: {'learning_rate': 0.045223194778238045, 'depth': 3, 'l2_leaf_reg': 0.01660820457924477, 'iterations': 550}. Best is trial 16 with value: 0.2511054289192964.
# Best parameters for CatBoost: {'learning_rate': 0.01008297465510277, 'depth': 4, 'l2_leaf_reg': 0.0035977161348057047, 'iterations': 107}

# %%
lgb_best_params = study_lgb.best_params
cat_best_params = study_cat.best_params

kf = KFold(n_splits=5, shuffle=True, random_state=42)
voting_r2 = []

for train_index, test_index in kf.split(X_pca):
    X_train_fold, X_test = X_pca[train_index], X_pca[test_index]
    y_train, y_test = y[train_index], y[test_index]

    lgb_model = lgb.LGBMRegressor(**lgb_best_params)
    cat_model = CatBoostRegressor(**cat_best_params)

    voting_model = VotingRegressor(estimators=[
        ('lgb', lgb_model),
        ('cat', cat_model)
    ])
    cat_model.fit(X_train_fold, y_train)
    lgb_model.fit(X_train_fold, y_train)
    voting_model.fit(X_train_fold, y_train)
    y_pred = voting_model.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    voting_r2.append(r2)

print(f'Voting Regressor R^2: {np.mean(voting_r2):.4f} ± {np.std(voting_r2):.4f}')
# Out:
# 0:	learn: 2.1558453	total: 21.9ms	remaining: 2.32s
# 1:	learn: 2.1515491	total: 23.7ms	remaining: 1.24s
# 2:	learn: 2.1463657	total: 25.2ms	remaining: 875ms
# 3:	learn: 2.1411267	total: 26.9ms	remaining: 692ms
# 4:	learn: 2.1370841	total: 28.7ms	remaining: 586ms
# 5:	learn: 2.1322583	total: 30.8ms	remaining: 519ms
# 6:	learn: 2.1267342	total: 32.6ms	remaining: 465ms
# 7:	learn: 2.1216082	total: 34.9ms	remaining: 432ms
# 8:	learn: 2.1164217	total: 36.5ms	remaining: 397ms
# 9:	learn: 2.1115522	total: 38.2ms	remaining: 371ms
# 10:	learn: 2.1066813	total: 39.8ms	remaining: 347ms
# 11:	learn: 2.1017890	total: 41.2ms	remaining: 326ms
# 12:	learn: 2.0979311	total: 43.9ms	remaining: 318ms
# 13:	learn: 2.0934654	total: 45.6ms	remaining: 303ms
# 14:	learn: 2.0894854	total: 48.3ms	remaining: 296ms
# 15:	learn: 2.0847065	total: 49.9ms	remaining: 284ms
# 16:	learn: 2.0806072	total: 51.5ms	remaining: 273ms
# 17:	learn: 2.0757735	total: 53.4ms	remaining: 264ms
# 18:	learn: 2.0710579	total: 55.5ms	remaining: 257ms
# 19:	learn: 2.0668607	total: 57.2ms	remaining: 249ms
# 20:	learn: 2.0624264	total: 58.9ms	remaining: 241ms
# 21:	learn: 2.0577099	total: 60.1ms	remaining: 232ms
# 22:	learn: 2.0537904	total: 61.6ms	remaining: 225ms
# 23:	learn: 2.0502093	total: 62.9ms	remaining: 218ms
# 24:	learn: 2.0456116	total: 64.3ms	remaining: 211ms
# 25:	learn: 2.0416432	total: 65.6ms	remaining: 204ms
# 26:	learn: 2.0371503	total: 66.9ms	remaining: 198ms
# 27:	learn: 2.0329616	total: 70.1ms	remaining: 198ms
# 28:	learn: 2.0300640	total: 72.1ms	remaining: 194ms
# 29:	learn: 2.0260743	total: 73.4ms	remaining: 189ms
# 30:	learn: 2.0227829	total: 74.9ms	remaining: 184ms
# 31:	learn: 2.0184508	total: 76.8ms	remaining: 180ms
# 32:	learn: 2.0147952	total: 78.4ms	remaining: 176ms
# 33:	learn: 2.0115759	total: 80.6ms	remaining: 173ms
# 34:	learn: 2.0089185	total: 82.1ms	remaining: 169ms
# 35:	learn: 2.0044317	total: 83.7ms	remaining: 165ms
# 36:	learn: 2.0009750	total: 85.1ms	remaining: 161ms
# 37:	learn: 1.9970882	total: 86.5ms	remaining: 157ms
# 38:	learn: 1.9935845	total: 88.1ms	remaining: 154ms
# 39:	learn: 1.9904033	total: 89.9ms	remaining: 151ms
# 104:	learn: 1.8197568	total: 148ms	remaining: 2.82ms
# 105:	learn: 1.8169761	total: 149ms	remaining: 1.41ms
# 106:	learn: 1.8150405	total: 150ms	remaining: 0us
# Voting Regressor R^2: 0.3167 ± 0.0119

# %%
import joblib

# %%
joblib.dump(voting_model, 'voting_regressor.joblib')
joblib.dump(lgb_model, 'LGBMRegressor.joblib')
joblib.dump(cat_model, 'CatBoostRegressor.joblib')
# Out:
# ['CatBoostRegressor.joblib']

# %%
common_cols = train_term1.columns.intersection(test_term1.columns)

# Tạo DataFrame mới chỉ chứa các cột chung
train_term1_common = train_term1[common_cols]
df_test_common = test_term1[common_cols]

# Tìm các hàng khác nhau
different_rows = pd.concat([train_term1_common, df_test_common]).drop_duplicates(keep=False)

different_rows.reset_index(drop=True, inplace=True)
different_rows.head(5)
# Out:
#                                    username  hour_0  hour_1  hour_2  hour_3  \
# 0  ed9eaeb6a707f50154024b24d7efcb874a9795dd     6.0     6.0     1.0     1.0
# 1  ba12c0a2cb367af0467e479c03507c71a805d291     1.0     3.0     7.0    10.0
# 2  b7298b0fe50443a623af9b56792b330c2d052845     0.0    24.0    28.0    39.0
# 3  c60be70309789b39355dc612f36e37090ccad5dc     0.0     4.0    20.0    13.0
# 4  a22a58c5be8aa2c2700619e37f2b7a6e4efa7e6b     0.0     6.0     0.0     0.0
#
#    hour_4  hour_5  hour_6  hour_7  hour_8  ...  num_problem  submit_count  \
# 0     6.0     8.0     5.0    11.0    17.0  ...           58           136
# 1    25.0     5.0    16.0    28.0    36.0  ...          112           313
# 2    22.0     2.0     2.0     4.0     7.0  ...          110           246
# 3     9.0     4.0     5.0    10.0    11.0  ...           83           172
# 4     1.0     1.0    19.0    38.0    55.0  ...          103           277
#
#    count_NON_SCORE  count_SCORE  count_is_final  mean_pre_score  \
# 0               34          102              58     5202.000000
# 1               74          239             117     5137.111821
# 2               36          210             110     5982.589431
# 3               26          146              83     6237.773256
# 4               38          239             103     5370.649819
#
#    count_of_assignments  ratio_not_10000  mean_submit_problem_x  \
# 0             27.200000         0.034483               2.344828
# 1             52.166667         0.000000               2.794643
# 2             49.200000         0.018182               2.236364
# 3             17.200000         0.084337               2.072289
# 4             25.181818         0.048544               2.689320
#
#    mean_submit_problem_y
# 0               0.177979
# 1               4.387548
# 2               1.547971
# 3               0.556678
# 4               0.961238
#
# [5 rows x 36 columns]

# %%
X_test= different_rows.drop(columns=["username"])

# %%
X_pca = np.asarray(X_test)

# %%
y_pre1 = lgb_model.predict(X_pca)
y_pre2 = cat_model.predict(X_pca)
y_pre3 = voting_model.predict(X_pca)

# %%
username = different_rows['username'].to_list()
results1 = []
for i, value in enumerate(y_pre1):
    results1.append((username[i], value))
df = pd.DataFrame(results1, columns=['file_name', 'label'])
df.to_csv('outputTH_1.csv', index=False, header=False)

# %%
results2 = []
for i, value in enumerate(y_pre2):
    results2.append((username[i], value))
df = pd.DataFrame(results2, columns=['file_name', 'label'])
df.to_csv('outputTH_2.csv', index=False, header=False)

# %%
results3 = []
for i, value in enumerate(y_pre3):
    results3.append((username[i], value))
df = pd.DataFrame(results3, columns=['file_name', 'label'])
df.to_csv('outputTH_3.csv', index=False, header=False)
